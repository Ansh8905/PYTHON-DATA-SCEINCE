# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
iris_df = sns.load_dataset('iris')
penguins_df = sns.load_dataset('penguins')

# %%
iris_df['sepal_length'].plot(kind='box')

# %%
iris_df[['species','sepal_length',]].plot(kind='box')

# %%
iris_df['species'].value_counts()

# %%
sns.boxenplot(data=iris_df,x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.violinplot(data=iris_df,x='petal_length',y='sepal_width')
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='sepal_width'>

# %%
sns.swarmplot(data=iris_df,x='sepal_length',y='sepal_width')

# %%
sns.scatterplot(data=iris_df,x='sepal_length',y='sepal_width',hue='sepal_width')

# %%
sns.jointplot(data=iris_df,x='sepal_length',y='sepal_width')

# %%
sns.pairplot(data=iris_df,hue='species')

# %%
penguins_df.dropna()      #kam_values missin hone pe chalana h
# Out:
# <bound method DataFrame.dropna of     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
sns.countplot(data=penguins_df,x='species')
#
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %%
wheterdf = pd
